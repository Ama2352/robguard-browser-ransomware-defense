# %% [markdown]
# # RøBguard — ML Training Pipeline
#
# This notebook covers the full pipeline:
# 1. Install dependencies
# 2. Generate original sample files
# 3. Generate the labeled dataset (entropy/size features)
# 4. Exploratory Data Analysis
# 5. Train & evaluate all 4 models (10-fold CV)
# 6. Compare results
# 7. Select the best model from actual results
# 8. Save & download model files

# %% [markdown]
# ## Stage 1 — Install Dependencies

# %%
# !pip install -q pycryptodome scikit-learn xgboost openpyxl python-docx reportlab python-pptx PyPDF2 pandas matplotlib seaborn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 8.7 MB/s eta 0:00:00

# %% [markdown]
# ## Stage 2 — Generate Original Sample Files

# %%
from pathlib import Path
import random

FILES_PER_TYPE = 50
BASE_DIR = Path('originals')
for d in ['txt','pdf','docx','xlsx','ppt']:
    (BASE_DIR / d).mkdir(parents=True, exist_ok=True)

WORDS = ['ransomware','browser','security','machine','learning','entropy',
         'detection','software','engineering','dataset','analysis','system',
         'document','research','classification']

def random_sentence():
    return ' '.join(random.choices(WORDS, k=random.randint(8, 20)))

print('Generating TXT...')
for i in range(FILES_PER_TYPE):
    with open(BASE_DIR / 'txt' / f'sample_{i}.txt', 'w') as f:
        for _ in range(random.randint(50, 200)):
            f.write(random_sentence() + '\n')

print('Generating DOCX...')
from docx import Document
for i in range(FILES_PER_TYPE):
    doc = Document()
    doc.add_heading(f'Document {i}', level=1)
    for _ in range(random.randint(20, 80)): doc.add_paragraph(random_sentence())
    doc.save(BASE_DIR / 'docx' / f'sample_{i}.docx')

print('Generating XLSX...')
from openpyxl import Workbook
for i in range(FILES_PER_TYPE):
    wb = Workbook(); ws = wb.active
    for r in range(1,101):
        for c in range(1,11): ws.cell(row=r, column=c, value=random.randint(1,100000))
    wb.save(BASE_DIR / 'xlsx' / f'sample_{i}.xlsx')

print('Generating PDF...')
from reportlab.pdfgen import canvas
for i in range(FILES_PER_TYPE):
    c = canvas.Canvas(str(BASE_DIR / 'pdf' / f'sample_{i}.pdf')); y = 800
    for _ in range(60):
        c.drawString(50, y, random_sentence()); y -= 12
        if y < 50: c.showPage(); y = 800
    c.save()

print('Generating PPT...')
from pptx import Presentation
for i in range(FILES_PER_TYPE):
    prs = Presentation()
    for si in range(random.randint(3, 8)):
        s = prs.slides.add_slide(prs.slide_layouts[1])
        s.shapes.title.text = f'Slide {si}'
        s.placeholders[1].text = random_sentence()
    prs.save(BASE_DIR / 'ppt' / f'sample_{i}.pptx')

print('Done.')
# Out:
# Generating TXT...
# Generating DOCX...
# Generating XLSX...
# Generating PDF...
# Generating PPT...
# Done.

# %% [markdown]
# ## Stage 3 — Generate Labeled Dataset

# %%
import os, math, csv, random
from io import BytesIO
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes

def entropy(b):
    if not b: return 0.0
    freq = {}
    for byte in b: freq[byte] = freq.get(byte, 0) + 1
    return -sum((c/len(b))*math.log2(c/len(b)) for c in freq.values())

def encrypt_bytes(b):
    key = get_random_bytes(32)
    cipher = AES.new(key, AES.MODE_CBC)
    pad_len = 16 - (len(b) % 16)
    return cipher.iv + cipher.encrypt(b + bytes([pad_len]*pad_len))

def benign_txt(text, n=100):
    words = text.split(); variants = []
    for i in range(n):
        w = words.copy()
        if i < n//2: w = w[:-random.randint(1, max(1, len(w)//4))]
        else: w += random.choices(w, k=random.randint(1, max(1, len(w)//4)))
        variants.append(' '.join(w).encode())
    return variants

def benign_docx(fpath, n=100):
    from docx import Document
    doc = Document(fpath); paras = [p.text for p in doc.paragraphs]
    words = [w for p in paras for w in p.split()]; variants = []
    for i in range(n):
        nd = Document()
        for p in paras: nd.add_paragraph(p)
        if i < n//2 and nd.paragraphs:
            p = nd.paragraphs[-1]; p._element.getparent().remove(p._element)
        else: nd.add_paragraph(' '.join(random.choices(words, k=10)))
        buf = BytesIO(); nd.save(buf); variants.append(buf.getvalue())
    return variants

def benign_xlsx(fpath, n=100):
    from openpyxl import load_workbook
    from openpyxl.utils import get_column_letter
    variants = []
    for i in range(n):
        wb = load_workbook(fpath); ws = wb.active
        if i < n//2 and ws.max_row > 1: ws.delete_rows(ws.max_row)
        else:
            col = get_column_letter(random.randint(1, min(ws.max_column,5)))
            ws[f'{col}{random.randint(1, min(ws.max_row+1,20))}'] = round(random.uniform(-1e6,1e6),4)
        buf = BytesIO(); wb.save(buf); variants.append(buf.getvalue())
    return variants

def benign_pdf(fpath, n=100):
    from PyPDF2 import PdfReader, PdfWriter
    reader = PdfReader(fpath); variants = []
    for i in range(n):
        w = PdfWriter()
        if i < n//2 and len(reader.pages) >= 2:
            for j in range(len(reader.pages)-1): w.add_page(reader.pages[j])
        else:
            for p in reader.pages: w.add_page(p)
            w.add_blank_page()
        buf = BytesIO(); w.write(buf); variants.append(buf.getvalue())
    return variants

def benign_pptx(fpath, n=100):
    from pptx import Presentation
    variants = []
    for i in range(n):
        prs = Presentation(fpath)
        xl = prs.slides._sldIdLst
        if i < n//2 and len(xl) > 1: xl.remove(xl[-1])
        else:
            s = prs.slides.add_slide(prs.slide_layouts[1])
            s.shapes.title.text = 'Benign'; s.placeholders[1].text = 'Generated'
        buf = BytesIO(); prs.save(buf); variants.append(buf.getvalue())
    return variants

def process_file(ext, fpath):
    rows = []
    with open(fpath, 'rb') as f: orig = f.read()
    e0 = entropy(orig); s0 = len(orig)
    try:
        if ext == 'txt':
            with open(fpath, 'r', errors='ignore') as f: text = f.read()
            variants = benign_txt(text)
        elif ext == 'pdf':  variants = benign_pdf(fpath)
        elif ext == 'docx': variants = benign_docx(fpath)
        elif ext == 'xlsx': variants = benign_xlsx(fpath)
        elif ext == 'ppt':  variants = benign_pptx(fpath)
        else: return []
        for vb in variants: rows.append([entropy(vb)-e0, len(vb)-s0, 0])
    except Exception as e:
        print(f'  WARN {fpath}: {e}')
    for _ in range(100):
        if random.random() < 0.05:
            split = max(16, int(len(orig)*random.uniform(0.1,0.3)))
            combined = encrypt_bytes(orig[:split]) + orig[split:]
        else:
            combined = encrypt_bytes(orig)
        rows.append([entropy(combined)-e0, len(combined)-s0, 1])
    return rows

tasks = []
for ext in ['txt','pdf','docx','xlsx','ppt']:
    folder = f'originals/{ext}'
    if os.path.exists(folder):
        for fname in os.listdir(folder): tasks.append((ext, f'{folder}/{fname}'))

with open('file_difference_dataset.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['entropy_diff', 'size_diff', 'label'])
    for idx, (ext, fpath) in enumerate(tasks, 1):
        print(f'[{idx}/{len(tasks)}] {ext}: {os.path.basename(fpath)}', end='', flush=True)
        try:
            result = process_file(ext, fpath)
            writer.writerows(result)
            print(f' -> {len(result)} rows')
        except Exception as e:
            print(f' -> ERROR: {e}')

print('\nDataset saved: file_difference_dataset.csv')
# Out:
# [1/250] txt: sample_15.txt -> 200 rows
# [2/250] txt: sample_17.txt -> 200 rows
# [3/250] txt: sample_43.txt -> 200 rows
# [4/250] txt: sample_23.txt -> 200 rows
# [5/250] txt: sample_44.txt -> 200 rows
# [6/250] txt: sample_33.txt -> 200 rows
# [7/250] txt: sample_6.txt -> 200 rows
# [8/250] txt: sample_46.txt -> 200 rows
# [9/250] txt: sample_0.txt -> 200 rows
# [10/250] txt: sample_5.txt -> 200 rows
# [11/250] txt: sample_12.txt -> 200 rows
# [12/250] txt: sample_13.txt -> 200 rows
# [13/250] txt: sample_36.txt -> 200 rows
# [14/250] txt: sample_4.txt -> 200 rows
# [15/250] txt: sample_28.txt -> 200 rows
# [16/250] txt: sample_38.txt -> 200 rows
# [17/250] txt: sample_20.txt -> 200 rows
# [18/250] txt: sample_31.txt -> 200 rows
# [19/250] txt: sample_18.txt -> 200 rows
# [20/250] txt: sample_34.txt -> 200 rows
# [21/250] txt: sample_24.txt -> 200 rows
# [22/250] txt: sample_27.txt -> 200 rows
# [23/250] txt: sample_7.txt -> 200 rows
# [24/250] txt: sample_22.txt -> 200 rows
# [25/250] txt: sample_49.txt -> 200 rows
# [26/250] txt: sample_47.txt -> 200 rows
# [27/250] txt: sample_41.txt -> 200 rows
# [28/250] txt: sample_8.txt -> 200 rows
# [29/250] txt: sample_42.txt -> 200 rows
# [30/250] txt: sample_26.txt -> 200 rows
# [31/250] txt: sample_37.txt -> 200 rows
# [32/250] txt: sample_40.txt -> 200 rows
# [33/250] txt: sample_39.txt -> 200 rows
# [34/250] txt: sample_25.txt -> 200 rows
# [35/250] txt: sample_1.txt -> 200 rows
# [36/250] txt: sample_2.txt -> 200 rows
# [37/250] txt: sample_35.txt -> 200 rows
# [38/250] txt: sample_16.txt -> 200 rows
# [39/250] txt: sample_9.txt -> 200 rows
# [40/250] txt: sample_30.txt -> 200 rows
# [41/250] txt: sample_21.txt -> 200 rows
# [42/250] txt: sample_45.txt -> 200 rows
# [43/250] txt: sample_32.txt -> 200 rows
# [44/250] txt: sample_48.txt -> 200 rows
# [45/250] txt: sample_14.txt -> 200 rows
# [46/250] txt: sample_29.txt -> 200 rows
# [47/250] txt: sample_10.txt -> 200 rows
# [48/250] txt: sample_11.txt -> 200 rows
# [49/250] txt: sample_19.txt -> 200 rows
# [50/250] txt: sample_3.txt -> 200 rows
# [51/250] pdf: sample_21.pdf -> 200 rows
# [52/250] pdf: sample_33.pdf -> 200 rows
# [53/250] pdf: sample_14.pdf -> 200 rows
# [54/250] pdf: sample_0.pdf -> 200 rows
# [55/250] pdf: sample_23.pdf -> 200 rows
# [56/250] pdf: sample_46.pdf -> 200 rows
# [57/250] pdf: sample_49.pdf -> 200 rows
# [58/250] pdf: sample_28.pdf -> 200 rows
# [59/250] pdf: sample_44.pdf -> 200 rows
# [60/250] pdf: sample_17.pdf -> 200 rows
# [61/250] pdf: sample_39.pdf -> 200 rows
# [62/250] pdf: sample_45.pdf -> 200 rows
# [63/250] pdf: sample_6.pdf -> 200 rows
# [64/250] pdf: sample_31.pdf -> 200 rows
# [65/250] pdf: sample_8.pdf -> 200 rows
# [66/250] pdf: sample_43.pdf -> 200 rows
# [67/250] pdf: sample_16.pdf -> 200 rows
# [68/250] pdf: sample_13.pdf -> 200 rows
# [69/250] pdf: sample_37.pdf -> 200 rows
# [70/250] pdf: sample_35.pdf -> 200 rows
# [71/250] pdf: sample_5.pdf -> 200 rows
# [72/250] pdf: sample_27.pdf -> 200 rows
# [73/250] pdf: sample_42.pdf -> 200 rows
# [74/250] pdf: sample_25.pdf -> 200 rows
# [75/250] pdf: sample_15.pdf -> 200 rows
# [76/250] pdf: sample_10.pdf -> 200 rows
# [77/250] pdf: sample_48.pdf -> 200 rows
# [78/250] pdf: sample_4.pdf -> 200 rows
# [79/250] pdf: sample_26.pdf -> 200 rows
# [80/250] pdf: sample_40.pdf -> 200 rows
# [81/250] pdf: sample_29.pdf -> 200 rows
# [82/250] pdf: sample_19.pdf -> 200 rows
# [83/250] pdf: sample_41.pdf -> 200 rows
# [84/250] pdf: sample_2.pdf -> 200 rows
# [85/250] pdf: sample_24.pdf -> 200 rows
# [86/250] pdf: sample_32.pdf -> 200 rows
# [87/250] pdf: sample_18.pdf -> 200 rows
# [88/250] pdf: sample_9.pdf -> 200 rows
# [89/250] pdf: sample_11.pdf -> 200 rows
# [90/250] pdf: sample_38.pdf -> 200 rows
# [91/250] pdf: sample_7.pdf -> 200 rows
# [92/250] pdf: sample_3.pdf -> 200 rows
# [93/250] pdf: sample_1.pdf -> 200 rows
# [94/250] pdf: sample_20.pdf -> 200 rows
# [95/250] pdf: sample_22.pdf -> 200 rows
# [96/250] pdf: sample_36.pdf -> 200 rows
# [97/250] pdf: sample_30.pdf -> 200 rows
# [98/250] pdf: sample_12.pdf -> 200 rows
# [99/250] pdf: sample_47.pdf -> 200 rows
# [100/250] pdf: sample_34.pdf -> 200 rows
# [101/250] docx: sample_37.docx -> 200 rows
# [102/250] docx: sample_13.docx -> 200 rows
# [103/250] docx: sample_20.docx -> 200 rows
# [104/250] docx: sample_41.docx -> 200 rows
# [105/250] docx: sample_47.docx -> 200 rows
# [106/250] docx: sample_21.docx -> 200 rows
# [107/250] docx: sample_18.docx -> 200 rows
# [108/250] docx: sample_22.docx -> 200 rows
# [109/250] docx: sample_44.docx -> 200 rows
# [110/250] docx: sample_45.docx -> 200 rows
# [111/250] docx: sample_23.docx -> 200 rows
# [112/250] docx: sample_42.docx -> 200 rows
# [113/250] docx: sample_48.docx -> 200 rows
# [114/250] docx: sample_49.docx -> 200 rows
# [115/250] docx: sample_14.docx -> 200 rows
# [116/250] docx: sample_32.docx -> 200 rows
# [117/250] docx: sample_8.docx -> 200 rows
# [118/250] docx: sample_46.docx -> 200 rows
# [119/250] docx: sample_25.docx -> 200 rows
# [120/250] docx: sample_17.docx -> 200 rows
# [121/250] docx: sample_3.docx -> 200 rows
# [122/250] docx: sample_36.docx -> 200 rows
# [123/250] docx: sample_12.docx -> 200 rows
# [124/250] docx: sample_33.docx -> 200 rows
# [125/250] docx: sample_43.docx -> 200 rows
# [126/250] docx: sample_0.docx -> 200 rows
# [127/250] docx: sample_27.docx -> 200 rows
# [128/250] docx: sample_5.docx -> 200 rows
# [129/250] docx: sample_24.docx -> 200 rows
# [130/250] docx: sample_30.docx -> 200 rows
# [131/250] docx: sample_4.docx -> 200 rows
# [132/250] docx: sample_39.docx -> 200 rows
# [133/250] docx: sample_7.docx -> 200 rows
# [134/250] docx: sample_40.docx -> 200 rows
# [135/250] docx: sample_6.docx -> 200 rows
# [136/250] docx: sample_31.docx -> 200 rows
# [137/250] docx: sample_1.docx -> 200 rows
# [138/250] docx: sample_28.docx -> 200 rows
# [139/250] docx: sample_11.docx -> 200 rows
# [140/250] docx: sample_15.docx -> 200 rows
# [141/250] docx: sample_16.docx -> 200 rows
# [142/250] docx: sample_26.docx -> 200 rows
# [143/250] docx: sample_9.docx -> 200 rows
# [144/250] docx: sample_29.docx -> 200 rows
# [145/250] docx: sample_34.docx -> 200 rows
# [146/250] docx: sample_38.docx -> 200 rows
# [147/250] docx: sample_19.docx -> 200 rows
# [148/250] docx: sample_10.docx -> 200 rows
# [149/250] docx: sample_2.docx -> 200 rows
# [150/250] docx: sample_35.docx -> 200 rows
# [151/250] xlsx: sample_28.xlsx -> 200 rows
# [152/250] xlsx: sample_19.xlsx -> 200 rows
# [153/250] xlsx: sample_4.xlsx -> 200 rows
# [154/250] xlsx: sample_29.xlsx -> 200 rows
# [155/250] xlsx: sample_35.xlsx -> 200 rows
# [156/250] xlsx: sample_10.xlsx -> 200 rows
# [157/250] xlsx: sample_25.xlsx -> 200 rows
# [158/250] xlsx: sample_39.xlsx -> 200 rows
# [159/250] xlsx: sample_0.xlsx -> 200 rows
# [160/250] xlsx: sample_7.xlsx -> 200 rows
# [161/250] xlsx: sample_38.xlsx -> 200 rows
# [162/250] xlsx: sample_12.xlsx -> 200 rows
# [163/250] xlsx: sample_44.xlsx -> 200 rows
# [164/250] xlsx: sample_30.xlsx -> 200 rows
# [165/250] xlsx: sample_16.xlsx -> 200 rows
# [166/250] xlsx: sample_14.xlsx -> 200 rows
# [167/250] xlsx: sample_9.xlsx -> 200 rows
# [168/250] xlsx: sample_40.xlsx -> 200 rows
# [169/250] xlsx: sample_48.xlsx -> 200 rows
# [170/250] xlsx: sample_17.xlsx -> 200 rows
# [171/250] xlsx: sample_11.xlsx -> 200 rows
# [172/250] xlsx: sample_6.xlsx -> 200 rows
# [173/250] xlsx: sample_3.xlsx -> 200 rows
# [174/250] xlsx: sample_5.xlsx -> 200 rows
# [175/250] xlsx: sample_36.xlsx -> 200 rows
# [176/250] xlsx: sample_21.xlsx -> 200 rows
# [177/250] xlsx: sample_49.xlsx -> 200 rows
# [178/250] xlsx: sample_13.xlsx -> 200 rows
# [179/250] xlsx: sample_27.xlsx -> 200 rows
# [180/250] xlsx: sample_18.xlsx -> 200 rows
# [181/250] xlsx: sample_33.xlsx -> 200 rows
# [182/250] xlsx: sample_43.xlsx -> 200 rows
# [183/250] xlsx: sample_32.xlsx -> 200 rows
# [184/250] xlsx: sample_24.xlsx -> 200 rows
# [185/250] xlsx: sample_23.xlsx -> 200 rows
# [186/250] xlsx: sample_42.xlsx -> 200 rows
# [187/250] xlsx: sample_34.xlsx -> 200 rows
# [188/250] xlsx: sample_20.xlsx -> 200 rows
# [189/250] xlsx: sample_46.xlsx -> 200 rows
# [190/250] xlsx: sample_41.xlsx -> 200 rows
# [191/250] xlsx: sample_31.xlsx -> 200 rows
# [192/250] xlsx: sample_8.xlsx -> 200 rows
# [193/250] xlsx: sample_22.xlsx -> 200 rows
# [194/250] xlsx: sample_1.xlsx -> 200 rows
# [195/250] xlsx: sample_45.xlsx -> 200 rows
# [196/250] xlsx: sample_2.xlsx -> 200 rows
# [197/250] xlsx: sample_26.xlsx -> 200 rows
# [198/250] xlsx: sample_37.xlsx -> 200 rows
# [199/250] xlsx: sample_47.xlsx -> 200 rows
# [200/250] xlsx: sample_15.xlsx -> 200 rows
# [201/250] ppt: sample_31.pptx -> 200 rows
# [202/250] ppt: sample_11.pptx -> 200 rows
# [203/250] ppt: sample_45.pptx -> 200 rows
# [204/250] ppt: sample_42.pptx -> 200 rows
# [205/250] ppt: sample_49.pptx -> 200 rows
# [206/250] ppt: sample_7.pptx -> 200 rows
# [207/250] ppt: sample_35.pptx -> 200 rows
# [208/250] ppt: sample_10.pptx -> 200 rows
# [209/250] ppt: sample_22.pptx -> 200 rows
# [210/250] ppt: sample_12.pptx -> 200 rows
# [211/250] ppt: sample_1.pptx -> 200 rows
# [212/250] ppt: sample_27.pptx -> 200 rows
# [213/250] ppt: sample_17.pptx -> 200 rows
# [214/250] ppt: sample_14.pptx -> 200 rows
# [215/250] ppt: sample_18.pptx -> 200 rows
# [216/250] ppt: sample_25.pptx -> 200 rows
# [217/250] ppt: sample_44.pptx -> 200 rows
# [218/250] ppt: sample_15.pptx -> 200 rows
# [219/250] ppt: sample_33.pptx -> 200 rows
# [220/250] ppt: sample_34.pptx -> 200 rows
# [221/250] ppt: sample_28.pptx -> 200 rows
# [222/250] ppt: sample_9.pptx -> 200 rows
# [223/250] ppt: sample_48.pptx -> 200 rows
# [224/250] ppt: sample_36.pptx -> 200 rows
# [225/250] ppt: sample_23.pptx -> 200 rows
# [226/250] ppt: sample_13.pptx -> 200 rows
# [227/250] ppt: sample_38.pptx -> 200 rows
# [228/250] ppt: sample_32.pptx -> 200 rows
# [229/250] ppt: sample_19.pptx -> 200 rows
# [230/250] ppt: sample_29.pptx -> 200 rows
# [231/250] ppt: sample_40.pptx -> 200 rows
# [232/250] ppt: sample_4.pptx -> 200 rows
# [233/250] ppt: sample_46.pptx -> 200 rows
# [234/250] ppt: sample_20.pptx -> 200 rows
# [235/250] ppt: sample_16.pptx -> 200 rows
# [236/250] ppt: sample_39.pptx -> 200 rows
# [237/250] ppt: sample_8.pptx -> 200 rows
# [238/250] ppt: sample_43.pptx -> 200 rows
# [239/250] ppt: sample_26.pptx -> 200 rows
# [240/250] ppt: sample_47.pptx -> 200 rows
# [241/250] ppt: sample_6.pptx -> 200 rows
# [242/250] ppt: sample_5.pptx -> 200 rows
# [243/250] ppt: sample_0.pptx -> 200 rows
# [244/250] ppt: sample_30.pptx -> 200 rows
# [245/250] ppt: sample_2.pptx -> 200 rows
# [246/250] ppt: sample_21.pptx -> 200 rows
# [247/250] ppt: sample_37.pptx -> 200 rows
# [248/250] ppt: sample_24.pptx -> 200 rows
# [249/250] ppt: sample_3.pptx -> 200 rows
# [250/250] ppt: sample_41.pptx -> 200 rows
#
# Dataset saved: file_difference_dataset.csv

# %% [markdown]
# ## Stage 4 — Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('file_difference_dataset.csv')
print('Shape:', df.shape)
print('Label distribution:\n', df['label'].value_counts())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for label, color, name in [(0,'steelblue','Benign'), (1,'crimson','Malicious')]:
    axes[0].hist(df[df['label']==label]['entropy_diff'], bins=60, alpha=0.7,
                 color=color, label=name)
axes[0].set_xlabel('entropy_diff (bits/byte)')
axes[0].set_title('Entropy Change Distribution')
axes[0].legend()

sample = df.sample(min(4000, len(df)), random_state=42)
axes[1].scatter(sample['entropy_diff'], sample['size_diff'],
                c=sample['label'].map({0:'steelblue',1:'crimson'}),
                alpha=0.4, s=10)
axes[1].set_xlabel('entropy_diff')
axes[1].set_ylabel('size_diff')
axes[1].set_title('Feature Space: Benign (blue) vs Malicious (red)')

plt.tight_layout()
plt.show()
# Out:
# Shape: (50000, 3)
# Label distribution:
#  label
# 0    25000
# 1    25000
# Name: count, dtype: int64

# %% [markdown]
# ## Stage 5 — Train All 4 Models (10-Fold Cross-Validation)

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from xgboost import XGBClassifier

X = df[['entropy_diff', 'size_diff']].values
y = df['label'].values

model_defs = {
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'KNN': KNeighborsClassifier(),
    'XGBoost': XGBClassifier(eval_metric='logloss', random_state=42),
}

kf = KFold(n_splits=10, shuffle=True, random_state=42)
cv_results = {}

for name, model in model_defs.items():
    accs, recalls, precisions, f1s = [], [], [], []

    for train_idx, test_idx in kf.split(X):
        X_tr, X_te = X[train_idx], X[test_idx]
        y_tr, y_te = y[train_idx], y[test_idx]

        # Fit scaler chỉ trên train fold để tránh data leakage
        scaler = StandardScaler()
        X_tr_scaled = scaler.fit_transform(X_tr)
        X_te_scaled = scaler.transform(X_te)

        model.fit(X_tr_scaled, y_tr)
        pred = model.predict(X_te_scaled)

        accs.append(accuracy_score(y_te, pred))
        precisions.append(precision_score(y_te, pred))
        recalls.append(recall_score(y_te, pred))
        f1s.append(f1_score(y_te, pred))

    cv_results[name] = {
        'Accuracy': round(sum(accs) / len(accs), 4),
        'Precision': round(sum(precisions) / len(precisions), 4),
        'Recall': round(sum(recalls) / len(recalls), 4),
        'F1': round(sum(f1s) / len(f1s), 4),
    }

# Tạo bảng kết quả
results_df = pd.DataFrame(cv_results).T
results_df = results_df[['Accuracy', 'Precision', 'Recall', 'F1']]

print("\nCross Validation Results:")
print(results_df)

# Vẽ bảng heatmap giống slide
plt.figure(figsize=(8, 3))

sns.heatmap(
    results_df,
    annot=True,
    fmt=".4f",
    cmap="Blues",
    linewidths=1,
    cbar=False
)

plt.title("Model Performance Comparison")
plt.tight_layout()
plt.show()

# Retrain full dataset để export model
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

trained_models = {}

for name, model in model_defs.items():
    model.fit(X_scaled, y)
    trained_models[name] = model

with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

with open("trained_models.pkl", "wb") as f:
    pickle.dump(trained_models, f)

print("\nFull-data training complete.")
# Out:
# Cross Validation Results:
#                Accuracy  Precision  Recall      F1
# Random Forest    0.9996     0.9995  0.9997  0.9996
# Decision Tree    0.9995     0.9996  0.9995  0.9995
# KNN              0.9996     0.9993  0.9999  0.9996
# XGBoost          0.9996     0.9995  0.9998  0.9996
# Full-data training complete.

# %% [markdown]
# ## Stage 6 — Results Comparison Table & Chart

# %%
results_df = pd.DataFrame(cv_results).T
print('\n=== Model Comparison (10-Fold CV) ===')
print(results_df.to_string())

ax = results_df.plot(kind='bar', figsize=(12, 5), ylim=(0.99, 1.001),
                     color=['#4C72B0','#DD8452','#55A868','#C44E52'])
ax.set_title('Model Comparison — All Metrics (10-Fold CV)', fontsize=14)
ax.set_xticklabels(results_df.index, rotation=15, ha='right')
ax.set_ylabel('Score')
ax.legend(loc='lower right')
plt.tight_layout()
plt.show()
# Out:
# === Model Comparison (10-Fold CV) ===
#                Accuracy  Precision  Recall      F1
# Random Forest    0.9996     0.9995  0.9997  0.9996
# Decision Tree    0.9995     0.9996  0.9995  0.9995
# KNN              0.9996     0.9993  0.9999  0.9996
# XGBoost          0.9996     0.9995  0.9998  0.9996

# %% [markdown]
# ## Stage 7 — Model Selection
#
# ### Why Recall is the Most Important Metric
#
# | Error type | What it means | Consequence |
# |---|---|---|
# | **False Negative** (FN) | Ransomware classified as benign | ❌ Files encrypted — **unrecoverable** |
# | **False Positive** (FP) | Legitimate edit classified as malicious | ⚠️ User gets an unnecessary warning — minor annoyance |
#
# **Cost(FN) >> Cost(FP)** → **Recall** = TP / (TP + FN) is the primary metric.
#
# Secondary: **Precision** — too many false positives cause alert fatigue and users start ignoring warnings.
#
# Accuracy and F1 are useful summaries but not the primary selection criteria here.
#
# The cell below selects the best model programmatically from the actual CV results.

# %%
# Select best model: primary = highest Recall, tiebreaker = highest Precision
sorted_models = results_df.sort_values(
    by=['Recall', 'Precision'], ascending=False
)

best_name = sorted_models.index[0]
best_scores = sorted_models.iloc[0]

print('=== Selection Result ===')
print(f'Best model : {best_name}')
print(f'Recall     : {best_scores["Recall"]}  (primary criterion)')
print(f'Precision  : {best_scores["Precision"]}  (tiebreaker)')
print(f'F1         : {best_scores["F1"]}')
print(f'Accuracy   : {best_scores["Accuracy"]}')
print()
print('Full ranking (by Recall then Precision):')
print(sorted_models[['Recall', 'Precision', 'F1', 'Accuracy']].to_string())
# Out:
# === Selection Result ===
# Best model : KNN
# Recall     : 0.9999  (primary criterion)
# Precision  : 0.9993  (tiebreaker)
# F1         : 0.9996
# Accuracy   : 0.9996
#
# Full ranking (by Recall then Precision):
#                Recall  Precision      F1  Accuracy
# KNN            0.9999     0.9993  0.9996    0.9996
# XGBoost        0.9998     0.9995  0.9996    0.9996
# Random Forest  0.9997     0.9995  0.9996    0.9996
# Decision Tree  0.9995     0.9996  0.9995    0.9995

# %% [markdown]
# ## Stage 8 — Save & Download Best Model

# %%
best_model = trained_models[best_name]

# Save as best_model.pkl — the demo system loads this file regardless of which model won
with open('best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
# Record which model was selected for reference
with open('best_model_name.txt', 'w') as f:
    f.write(best_name)

print(f'Saved best_model.pkl  ({best_name})')
print(f'Saved scaler.pkl')
print()
print('Place best_model.pkl and scaler.pkl in the models/ folder of the demo project.')
# Out:
# Saved best_model.pkl  (KNN)
# Saved scaler.pkl
#
# Place best_model.pkl and scaler.pkl in the models/ folder of the demo project.

# %%
# Download from Colab to your local machine
from google.colab import files
files.download('best_model.pkl')
files.download('scaler.pkl')
files.download('best_model_name.txt')
